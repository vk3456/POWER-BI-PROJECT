# %% [markdown]
# # Data Visualisation I - Matplotlib
#
# The ones who are already familiar with Matlab will realize that Matplotlib has a very similar style and properties. We can also think of matplotlib as Matlab plot's python version (which was actually the aim behind the project). It is a very strong library for creating 2D/3D static,animations and interactive visuals.
#
# Before we start exploring this library with examples, I strongly suggest you guys to visit https://matplotlib.org/ and have a look at the documentation and examples.

# %% [markdown]
# ## Installation
#
# For those of you who don't use JupyterNootebook:
#
# ## Anaconda distribution:
#     conda install matplotlib
# ## Python-pip:
#     pip install matplotlib
#
#
# After installating, let's import pyplot from matplotlib as plt (by convention) and numpy as np:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


# %matplotlib inline

# %%
x = np.linspace(0,5,21)
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  ])

# %%
y1 = 2**x
y2 = 5**x

# %% [markdown]
# ## Simple line plot

# %%
plt.plot(x,y1)
plt.xlabel('Effort',fontsize=10)
plt.ylabel('Earnings',fontsize=15)
plt.title('Life',fontsize=15)
#plt.show()   if not on JupyterNotebook, it's necessary to show the plot
# Out:
# Text(0.5, 1.0, 'Life')

# %% [markdown]
# ## Multiplots on same canvas

# %%
plt.subplot(1,2,1)  # rows,columns,which graph
plt.plot(x,y1,'r')

plt.subplot(1,2,2) 
plt.plot(x,y2,'k')

# %% [markdown]
# ## Object oriented plotting
# Involves instantiating a plot object and then calling methods and attributes of that object to modify the plots properties.

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1]) #left, bottom, length, height

axes.plot(x,y1)
axes.set_xlabel('Effort',fontsize=15)
axes.set_ylabel('Earnings',fontsize=15)
axes.set_title('Life',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Life')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1])  #left, bottom, length, height
axes2 = fig.add_axes([0.12,0.6,0.4,0.3])
#axes3 = fig.add_axes([1,0,1,1])

axes1.plot(x,y2,'r')
axes1.set_xlabel('effort1',fontsize=15)
axes1.set_ylabel('earnings',fontsize=15)
axes1.set_title('Real Life',fontsize=15)

axes2.plot(x,y1,'b')
axes2.set_xlabel('effort2')
axes2.set_ylabel('earnings')
axes2.set_title('Dream Life')
# Out:
# Text(0.5, 1.0, 'Dream Life')

# %%
print(axes2)
# Out:
# Axes(0.12,0.6;0.4x0.3)

# %% [markdown]
# ## Multiplots (OOP)

# %%
fig, axes = plt.subplots(1,2)

axes[0].plot(x,y1,'r')
axes[0].set_xlabel('effort',fontsize=15)
axes[0].set_ylabel('earnings',fontsize=15)
axes[0].set_title('Life 1',fontsize=15)

axes[1].plot(x,y2,'b')
axes[1].set_title('Life 2',fontsize=15)

fig.tight_layout()

# %%
for item in axes:
    print(item)
# Out:
# AxesSubplot(0.114699,0.1625;0.380035x0.7375)
# AxesSubplot(0.594965,0.1625;0.380035x0.7375)

# %% [markdown]
# ## Figure Size

# %%
fig = plt.figure(figsize=(4,3))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y1)

# %%
fig, axes = plt.subplots(1,2,figsize=(8,4))

axes[0].plot(x,y1)
axes[1].plot(x,y2)

fig.tight_layout()

# %%
for item in axes:
    print(item)
# Out:
# AxesSubplot(0.0530382,0.0965278;0.426519x0.865972)
# AxesSubplot(0.554731,0.0965278;0.426519x0.865972)

# %% [markdown]
# ## Adding legends

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])
axes.plot(x,y1,label='level1')
axes.plot(x,y2,label='level2')

axes.legend(loc='upper left')

# %% [markdown]
# ## Customize Figures

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])
axes.plot(x,y1,color='red',linestyle='--',
         linewidth=1,alpha=0.5,
         marker='*',markersize=30,
         markerfacecolor='yellow',
         markeredgecolor='blue',
         markeredgewidth=5)             # color RGB hex code
                                        # alpha --> tranparency

axes.set_xlim([0,3])
# Out:
# (0.0, 3.0)

# %% [markdown]
# ## Saving Figures

# %%
fig

# %%
fig.savefig('first_plot.png',dpi=300) # dpi -> Dots per inch (resolution)

# %% [markdown]
# # Plot types

# %% [markdown]
# ### scatter plot

# %%
import pandas as pd
from pandas import Series,DataFrame

# %%
df = pd.read_csv('data_car_cross.csv',index_col=0)

df.head()
# Out:
#     mpg  cylinder  displacement  horse power  weight  acceleration  year  \
# 0  18.0         8         307.0        130.0  3504.0          12.0    70
# 1  15.0         8         350.0        165.0  3693.0          11.5    70
# 2  18.0         8         318.0        150.0  3436.0          11.0    70
# 3  16.0         8         304.0        150.0  3433.0          12.0    70
# 4  17.0         8         302.0        140.0  3449.0          10.5    70
#
#    origin                         name
# 0       1  "chevrolet chevelle malibu"
# 1       1          "buick skylark 320"
# 2       1         "plymouth satellite"
# 3       1              "amc rebel sst"
# 4       1                "ford torino"

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])
axes.set_xlabel('Horse Power')
axes.set_ylabel('Weight')
axes.scatter(df['horse power'],df['weight'])

# %% [markdown]
# ### histogram plot

# %%
plt.hist(df['cylinder'])
plt.xlabel('Number of cylinders')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### boxplot

# %%
np_array = np.array(df[['mpg','acceleration']])

plt.boxplot(np_array)
plt.xticks([1,2],['Miles per gallon','acceleration'])
# Out:
# ([<matplotlib.axis.XTick at 0xbd24d60>, <matplotlib.axis.XTick at 0xbd24e50>],
#  [Text(0, 0, 'Miles per gallon'), Text(0, 0, 'acceleration')])

# %%
df1 = pd.read_csv("D:\\Covid-19.csv")

# %%
df1.head(10)
# Out:
#   S_no State/UT Confirmed Deaths  Recovered         DISTRICT CONFIRMED  \
# 0    1       MH    254427  10289   140325.0           MUMBAI     92988
# 1    2       TN    138470   1966    89532.0          CHENNAI     77338
# 2    3       DL    112495   3317    89969.0            THANE     61869
# 3    4       GJ     41820   2045    29162.0             PUNE     39125
# 4    5       KA     38843    689    15430.0        HYDERABAD     26574
# 5    6       UP     36476    935    23344.0        AHMEDABAD     23095
# 6    7       TG     34671    356    22485.0  BENGALURU URBAN     18387
# 7    8       WB     30013    935    18551.0          PALGHAR      9744
# 8    9   ANDHRA     29168    358    15412.0          KOLKATA      9608
# 9   10       RJ     24397    510    18103.0           RAIGAD      8459
#
#   Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0        NaN         NaN         NaN          NaN          NaN          NaN
# ...

# %%
df1
# Out:
#     S_no State/UT Confirmed Deaths  Recovered   DISTRICT CONFIRMED Unnamed: 7  \
# 0      1       MH    254427  10289   140325.0     MUMBAI     92988        NaN
# 1      2       TN    138470   1966    89532.0    CHENNAI     77338        NaN
# 2      3       DL    112495   3317    89969.0      THANE     61869        NaN
# 3      4       GJ     41820   2045    29162.0       PUNE     39125        NaN
# 4      5       KA     38843    689    15430.0  HYDERABAD     26574        NaN
# ..   ...      ...       ...    ...        ...        ...       ...        ...
# 836  NaN      NaN       NaN    NaN        NaN        NaN       NaN        NaN
# 837  NaN      NaN       NaN    NaN        NaN        NaN       NaN        NaN
# 838  NaN      NaN       NaN    NaN        NaN        NaN       NaN        NaN
# 839  NaN      NaN       NaN    NaN        NaN        NaN       NaN        NaN
# 840  NaN      NaN       NaN    NaN        NaN        NaN       NaN        NaN
#
# ...

# %%
df1[(df1["State/UT"]=="DL")| (df1["Deaths"]=="DL")].count
# Out:
# S_no           3387310814317821324828331835338842345849352856...
# State/UT              DLDLDLDLDLDLDLDLDLDLDLDLDLDLDLDLDLDLDLDLDL
# Confirmed      1124951124951124951124951124951124951124951124...
# Deaths         3317331733173317331733173317331733173317331733...
# Recovered                                            1.88935e+06
# DISTRICT       THANECHITTOORVILUPPURAMBIKANERHASSANNAWADAAYOD...
# CONFIRMED      6186926681459893685560444385330285239201170193...
# Unnamed: 7                                                     0
# Unnamed: 8                                                     0
# Unnamed: 9                                                     0
# Unnamed: 10                                                    0
# Unnamed: 11                                                    0
# Unnamed: 12                                                    0
# Unnamed: 13                                                    0
# ...
